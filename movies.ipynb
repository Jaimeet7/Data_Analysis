# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h1>Data Cleaning and Analysis</h1>

# %%
df = pd.read_csv('MoviesOnStreamingPlatforms_updated.csv')
df
# Out:
#        Unnamed: 0     ID                           Title  Year  Age  IMDb  \
# 0               0      1                       Inception  2010  13+   8.8
# 1               1      2                      The Matrix  1999  18+   8.7
# 2               2      3          Avengers: Infinity War  2018  13+   8.5
# 3               3      4              Back to the Future  1985   7+   8.5
# 4               4      5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...           ...    ...                             ...   ...  ...   ...
# 16739       16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740       16740  16741                  The Poof Point  2001   7+   4.7
# 16741       16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742       16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743       16743  16744                In Beaver Valley  1950  NaN   NaN
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0                 87%        1     0            0        0     0
# 1                 87%        1     0            0        0     0
# 2                 84%        1     0            0        0     0
# 3                 96%        1     0            0        0     0
# 4                 97%        1     0            1        0     0
# ...               ...      ...   ...          ...      ...   ...
# 16739             NaN        0     0            0        1     0
# 16740             NaN        0     0            0        1     0
# 16741             NaN        0     0            0        1     0
# 16742             NaN        0     0            0        1     0
# 16743             NaN        0     0            0        1     0
#
#                             Directors                            Genres  \
# 0                   Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1      Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2             Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                     Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                        Sergio Leone                           Western
# ...                               ...                               ...
# 16739                    Bruce Bilson      Comedy,Family,Fantasy,Horror
# 16740                     Neal Israel              Comedy,Family,Sci-Fi
# 16741                    Neil Gelinas                       Documentary
# 16742            Richard Slater-Jones                       Documentary
# 16743                     James Algar          Documentary,Short,Family
#
#                             Country                 Language  Runtime
# 0      United States,United Kingdom  English,Japanese,French    148.0
# 1                     United States                  English    136.0
# 2                     United States                  English    149.0
# 3                     United States                  English    116.0
# 4          Italy,Spain,West Germany                  Italian    161.0
# ...                             ...                      ...      ...
# 16739                 United States                  English    120.0
# 16740                 United States                  English     90.0
# 16741                 United States                  English      NaN
# 16742                 United States                  English      NaN
# 16743                 United States                  English     32.0
#
# [16744 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       16744 non-null  int64
#  1   ID               16744 non-null  int64
#  2   Title            16744 non-null  object
#  3   Year             16744 non-null  int64
#  4   Age              7354 non-null   object
#  5   IMDb             16173 non-null  float64
#  6   Rotten Tomatoes  5158 non-null   object
#  7   Netflix          16744 non-null  int64
#  8   Hulu             16744 non-null  int64
#  9   Prime Video      16744 non-null  int64
#  10  Disney+          16744 non-null  int64
#  11  Type             16744 non-null  int64
#  12  Directors        16018 non-null  object
#  13  Genres           16469 non-null  object
#  14  Country          16309 non-null  object
#  15  Language         16130 non-null  object
#  16  Runtime          16152 non-null  float64
# dtypes: float64(2), int64(8), object(7)
# memory usage: 2.2+ MB

# %% [markdown]
# Observation -
# 1. Age has lots of missing values ( can be dropped )
# 2. Rotten Tamatoes also has lot of missing values (wil be important for analysis purpose so try replacing with mean or median)
# 3. Directors have few missing values (drop since it is character data)
# 4. Genres has few missing values (drop because name data)
# 5. Country also has few missing values (drop name data)
# 6. Language has few missing values(drop name data or replace with most occured)
# 7. Runtime has few missing values(replace with mean or median)

# %%
df.duplicated().any() 
# No duplicate rows
# Out:
# np.False_

# %%
df = df.sort_values('Year')
df = df.reset_index(drop=True)

# %%
# sns.boxplot(df['Rotten Tomatoes'])
# No outliers 
# Replace with mean

# %%
df['Rotten Tomatoes'] = df['Rotten Tomatoes'].str.strip('%')
df['Rotten Tomatoes'] = df['Rotten Tomatoes'].astype(dtype=float)

df['Rotten Tomatoes'] = df['Rotten Tomatoes'].fillna(df['Rotten Tomatoes'].mean())/10
df
# Out:
#        Unnamed: 0     ID                                      Title  Year  \
# 0            4467   4468                         A Trip to the Moon  1902
# 1            8795   8796               From the Manger to the Cross  1912
# 2            9917   9918                      Fatty Joins the Force  1913
# 3           10170  10171                            The Speed Kings  1913
# 4            4912   4913                      The Birth of a Nation  1915
# ...           ...    ...                                        ...   ...
# 16739        2050   2051  Carmen Sandiego: To Steal or Not to Steal  2020
# 16740        5337   5338                 M.O.M. Mothers of Monsters  2020
# 16741        1613   1614                                Lady Driver  2020
# 16742        2537   2538           Go! Go! Cory Carson: The Chrissy  2020
# 16743       16568  16569                                  Lamp Life  2020
#
#        Age  IMDb  Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0      all   8.2        10.000000        0     0            1        0     0
# 1       7+   5.7         6.542846        0     0            1        0     0
# 2      NaN   5.3         6.542846        0     0            1        0     0
# 3      NaN   5.0         6.542846        0     0            1        0     0
# 4       7+   6.4         9.300000        0     0            1        0     0
# ...    ...   ...              ...      ...   ...          ...      ...   ...
# 16739  NaN   6.8         6.542846        1     0            0        0     0
# 16740  18+   5.3         7.300000        0     0            1        0     0
# 16741   7+   6.6         6.542846        1     0            0        0     0
# 16742  all   7.3         6.542846        1     0            0        0     0
# 16743  NaN   6.7         6.542846        0     0            0        1     0
#
#                      Directors                                        Genres  \
# 0               Georges Méliès  Short,Action,Adventure,Comedy,Fantasy,Sci-Fi
# 1                Sidney Olcott                               Biography,Drama
# 2               George Nichols                                  Comedy,Short
# 3                Wilfred Lucas                           Short,Action,Comedy
# 4                D.W. Griffith                             Drama,History,War
# ...                        ...                                           ...
# 16739  Jos Humphrey,Kenny Park       Animation,Short,Action,Adventure,Family
# 16740              Tucia Lyman                                      Thriller
# 16741     Shaun Paul Piccinino                                         Sport
# 16742   Stanley Moore,Alex Woo                        Animation,Short,Family
# 16743         Valerie LaPointe                Animation,Short,Family,Fantasy
#
#                     Country     Language  Runtime
# 0                    France  None,French     13.0
# 1             United States      English     60.0
# 2             United States      English     12.0
# 3             United States      English      8.0
# 4             United States          NaN    195.0
# ...                     ...          ...      ...
# 16739  Canada,United States      English     31.0
# 16740         United States      English     98.0
# 16741         United States      English    104.0
# 16742         United States      English     42.0
# 16743         United States      English      7.0
#
# [16744 rows x 17 columns]

# %%
# sns.boxplot(df['IMDb'])
# Lots of outliers
# replace empty rows with median

# %%
df['IMDb'] = df['IMDb'].fillna(df['IMDb'].median())

# %%
# since age has too many missing values we will drop

# %%
df = df.drop(columns=['Age','Unnamed: 0','Country','Type'])

# %%
df['Directors'] = df['Directors'].fillna('unkown')

# %%
# sns.boxplot(df['Runtime'])
# Lot of outliers
# replace with median

# %%
df['Language'] = df['Language'].fillna('unknown')

# %%
df['Runtime'] = df['Runtime'].fillna(df['Runtime'].median())

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               16744 non-null  int64
#  1   Title            16744 non-null  object
#  2   Year             16744 non-null  int64
#  3   IMDb             16744 non-null  float64
#  4   Rotten Tomatoes  16744 non-null  float64
#  5   Netflix          16744 non-null  int64
#  6   Hulu             16744 non-null  int64
#  7   Prime Video      16744 non-null  int64
#  8   Disney+          16744 non-null  int64
#  9   Directors        16744 non-null  object
#  10  Genres           16469 non-null  object
#  11  Language         16744 non-null  object
#  12  Runtime          16744 non-null  float64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 1.7+ MB
#           ID                                      Title  Year  IMDb  \
# 0       4468                         A Trip to the Moon  1902   8.2
# 1       8796               From the Manger to the Cross  1912   5.7
# 2       9918                      Fatty Joins the Force  1913   5.3
# 3      10171                            The Speed Kings  1913   5.0
# 4       4913                      The Birth of a Nation  1915   6.4
# ...      ...                                        ...   ...   ...
# 16739   2051  Carmen Sandiego: To Steal or Not to Steal  2020   6.8
# 16740   5338                 M.O.M. Mothers of Monsters  2020   5.3
# 16741   1614                                Lady Driver  2020   6.6
# 16742   2538           Go! Go! Cory Carson: The Chrissy  2020   7.3
# 16743  16569                                  Lamp Life  2020   6.7
#
#        Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  \
# 0            10.000000        0     0            1        0
# 1             6.542846        0     0            1        0
# 2             6.542846        0     0            1        0
# 3             6.542846        0     0            1        0
# 4             9.300000        0     0            1        0
# ...                ...      ...   ...          ...      ...
# 16739         6.542846        1     0            0        0
# 16740         7.300000        0     0            1        0
# 16741         6.542846        1     0            0        0
# 16742         6.542846        1     0            0        0
# 16743         6.542846        0     0            0        1
#
#                      Directors                                        Genres  \
# 0               Georges Méliès  Short,Action,Adventure,Comedy,Fantasy,Sci-Fi
# 1                Sidney Olcott                               Biography,Drama
# 2               George Nichols                                  Comedy,Short
# 3                Wilfred Lucas                           Short,Action,Comedy
# 4                D.W. Griffith                             Drama,History,War
# ...                        ...                                           ...
# 16739  Jos Humphrey,Kenny Park       Animation,Short,Action,Adventure,Family
# 16740              Tucia Lyman                                      Thriller
# 16741     Shaun Paul Piccinino                                         Sport
# 16742   Stanley Moore,Alex Woo                        Animation,Short,Family
# 16743         Valerie LaPointe                Animation,Short,Family,Fantasy
#
#           Language  Runtime
# 0      None,French     13.0
# 1          English     60.0
# 2          English     12.0
# 3          English      8.0
# 4          unknown    195.0
# ...            ...      ...
# 16739      English     31.0
# 16740      English     98.0
# 16741      English    104.0
# 16742      English     42.0
# 16743      English      7.0
#
# [16744 rows x 13 columns]

# %%
platform_df = pd.melt(df,id_vars=(['Title','IMDb','Year','Rotten Tomatoes']),value_vars=('Netflix','Hulu','Prime Video','Disney+'),var_name='Platform',value_name='Available')
# platform_df['Available'] = platform_df['Available'].replace({0:None})
# platform_df = platform_df.dropna()
platform_df=platform_df[platform_df['Available']==1].drop(columns=['Available']).reset_index(drop=True)
platform_df
# Out:
#                                     Title  IMDb  Year  Rotten Tomatoes  \
# 0                    The Battle of Midway   6.1  1942         6.542846
# 1            Why We Fight: Prelude to War   7.0  1942         6.542846
# 2               Report from the Aleutians   6.4  1943         6.542846
# 3      Why We Fight: The Battle of Russia   7.1  1943         6.542846
# 4                        Tunisian Victory   6.6  1944         6.542846
# ...                                   ...   ...   ...              ...
# 17376                            Stargirl   6.2  2020         7.100000
# 17377   Timmy Failure: Mistakes Were Made   6.1  2020         8.800000
# 17378          Penguins: Life on the Edge   6.9  2020         6.542846
# 17379                Diving with Dolphins   7.5  2020         6.542846
# 17380                           Lamp Life   6.7  2020         6.542846
#
#       Platform
# 0      Netflix
# 1      Netflix
# 2      Netflix
# 3      Netflix
# 4      Netflix
# ...        ...
# 17376  Disney+
# 17377  Disney+
# 17378  Disney+
# 17379  Disney+
# 17380  Disney+
#
# [17381 rows x 5 columns]

# %%
def fun(d):
    if d['Runtime']<=30:
        return "Short movie"
    elif 31<=d['Runtime']<=90:
        return "Long movie"
    else:
        return "Series"
    
df['runtime_category']=df.apply(fun,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                16744 non-null  int64
#  1   Title             16744 non-null  object
#  2   Year              16744 non-null  int64
#  3   IMDb              16744 non-null  float64
#  4   Rotten Tomatoes   16744 non-null  float64
#  5   Netflix           16744 non-null  int64
#  6   Hulu              16744 non-null  int64
#  7   Prime Video       16744 non-null  int64
#  8   Disney+           16744 non-null  int64
#  9   Directors         16744 non-null  object
#  10  Genres            16469 non-null  object
#  11  Language          16744 non-null  object
#  12  Runtime           16744 non-null  float64
#  13  runtime_category  16744 non-null  object
# dtypes: float64(3), int64(6), object(5)
# memory usage: 1.8+ MB

# %%
df
# Out:
#           ID                                      Title  Year  IMDb  \
# 0       4468                         A Trip to the Moon  1902   8.2
# 1       8796               From the Manger to the Cross  1912   5.7
# 2       9918                      Fatty Joins the Force  1913   5.3
# 3      10171                            The Speed Kings  1913   5.0
# 4       4913                      The Birth of a Nation  1915   6.4
# ...      ...                                        ...   ...   ...
# 16739   2051  Carmen Sandiego: To Steal or Not to Steal  2020   6.8
# 16740   5338                 M.O.M. Mothers of Monsters  2020   5.3
# 16741   1614                                Lady Driver  2020   6.6
# 16742   2538           Go! Go! Cory Carson: The Chrissy  2020   7.3
# 16743  16569                                  Lamp Life  2020   6.7
#
#        Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  \
# 0            10.000000        0     0            1        0
# 1             6.542846        0     0            1        0
# 2             6.542846        0     0            1        0
# 3             6.542846        0     0            1        0
# 4             9.300000        0     0            1        0
# ...                ...      ...   ...          ...      ...
# 16739         6.542846        1     0            0        0
# 16740         7.300000        0     0            1        0
# 16741         6.542846        1     0            0        0
# 16742         6.542846        1     0            0        0
# 16743         6.542846        0     0            0        1
#
#                      Directors                                        Genres  \
# 0               Georges Méliès  Short,Action,Adventure,Comedy,Fantasy,Sci-Fi
# 1                Sidney Olcott                               Biography,Drama
# 2               George Nichols                                  Comedy,Short
# 3                Wilfred Lucas                           Short,Action,Comedy
# 4                D.W. Griffith                             Drama,History,War
# ...                        ...                                           ...
# 16739  Jos Humphrey,Kenny Park       Animation,Short,Action,Adventure,Family
# 16740              Tucia Lyman                                      Thriller
# 16741     Shaun Paul Piccinino                                         Sport
# 16742   Stanley Moore,Alex Woo                        Animation,Short,Family
# 16743         Valerie LaPointe                Animation,Short,Family,Fantasy
#
#           Language  Runtime runtime_category
# 0      None,French     13.0      Short movie
# 1          English     60.0       Long movie
# 2          English     12.0      Short movie
# 3          English      8.0      Short movie
# 4          unknown    195.0           Series
# ...            ...      ...              ...
# 16739      English     31.0       Long movie
# 16740      English     98.0           Series
# 16741      English    104.0           Series
# 16742      English     42.0       Long movie
# 16743      English      7.0      Short movie
#
# [16744 rows x 14 columns]

# %%
platform_df
# Out:
#                                     Title  IMDb  Year  Rotten Tomatoes  \
# 0                    The Battle of Midway   6.1  1942         6.542846
# 1            Why We Fight: Prelude to War   7.0  1942         6.542846
# 2               Report from the Aleutians   6.4  1943         6.542846
# 3      Why We Fight: The Battle of Russia   7.1  1943         6.542846
# 4                        Tunisian Victory   6.6  1944         6.542846
# ...                                   ...   ...   ...              ...
# 17376                            Stargirl   6.2  2020         7.100000
# 17377   Timmy Failure: Mistakes Were Made   6.1  2020         8.800000
# 17378          Penguins: Life on the Edge   6.9  2020         6.542846
# 17379                Diving with Dolphins   7.5  2020         6.542846
# 17380                           Lamp Life   6.7  2020         6.542846
#
#       Platform
# 0      Netflix
# 1      Netflix
# 2      Netflix
# 3      Netflix
# 4      Netflix
# ...        ...
# 17376  Disney+
# 17377  Disney+
# 17378  Disney+
# 17379  Disney+
# 17380  Disney+
#
# [17381 rows x 5 columns]

# %% [markdown]
# <h1>Analysis</h1>

# %% [markdown]
# 1. Count the total movies

# %%
len(df['Title'])
# Out:
# 16744

# %% [markdown]
# Observation - Total movies = 16744

# %% [markdown]
# 2. Get movies that are released after 2007

# %%
len(df.query('Year>2007'))
# Out:
# 10754

# %% [markdown]
# Observation - Number of Movies released after 2007 = 10754

# %% [markdown]
# 3. Get the count of comedy genres

# %%
len(df.query('Genres=="Comedy"'))
# Out:
# 1040

# %% [markdown]
# Observation - Comedy Movies = 1040

# %% [markdown]
# 4. No of movies available in each platform

# %%
platform_df.groupby(['Platform','Available']).agg({'Available':'count'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 platform_df.groupby(['Platform','Available']).agg({'Available':'count'})
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Available'

# %% [markdown]
# Observation -
# 1. 564 Movies available on Disney+
# 2. 903 Movies available on Hulu
# 3. 3560 Movies available on Netflix
# 4. 12354 Movies available on Prime Video

# %% [markdown]
# 5. Highest Occurence of language

# %%
df['Language'].value_counts().idxmax()
# Out:
# 'English'

# %% [markdown]
# 6. Movie with highest IMDb rating

# %%
df.loc[df['IMDb'].idxmax(),['Title']]
# Out:
# Title    Steven Banks: Home Entertainment Center
# Name: 3005, dtype: object

# %% [markdown]
# 7. Released year wise no of movies,avg and highest IMDb rating

# %%
platform_df.groupby('Year').agg({'Title':'count',"IMDb":"max","IMDb":"mean"})
# Out:
#       Title      IMDb
# Year
# 1902      4  8.200000
# 1912      4  5.700000
# 1913      8  5.150000
# 1915     16  5.550000
# 1916      4  7.800000
# ...     ...       ...
# 2016   4824  5.827032
# 2017   5604  5.922198
# 2018   5140  5.896732
# 2019   2756  6.044267
# 2020    588  6.165306
#
# [109 rows x 2 columns]

# %% [markdown]
# Observation - Most number of movies released in the year 2017 and highest IMDb rating was 8.2 in the year 1902

# %% [markdown]
# 8. Get the top 5 directors based on movie count

# %%
count_df = df.groupby('Directors').agg({'Title':'count'}).sort_values(by='Title')
count_df.tail(6)
# Out:
#               Title
# Directors
# Jim Wynorski     22
# Sam Newfield     22
# Cheh Chang       26
# Joseph Kane      30
# Jay Chapman      36
# unkown          726

# %% [markdown]
# Observation -
# 1. Jay Chapman - 36
# 2. Joseph Kane - 30
# 3. Cheh Chang - 26
# 4. Sam Newfield - 22
# 5. Jim Wynorski - 22

# %% [markdown]
# <h1>Data Plots</h1>

# %% [markdown]
# 1. Plot the no of movies in each platform

# %%
plt.figure(figsize=(4,4))
sns.countplot(platform_df,x="Platform", hue="Available")
plt.title("Movies available and unavailable on each platform")
plt.show()

# %% [markdown]
# Observation - Most movies available on Prime video

# %% [markdown]
# 2. Plot the PLatform wise avg imdb rating

# %%
plt.figure(figsize=(7,7))
sns.barplot(platform_df,x="Platform",y="IMDb",estimator='mean')
plt.title("Average IMDb rating on each platform")
plt.show()

# %% [markdown]
# Observation - Movies on Disney+ have the highest average IMDb rating

# %% [markdown]
# Plot the percentage of each runtime

# %%
val = df['runtime_category'].value_counts().values
idx = df['runtime_category'].value_counts().index
print(val,idx)
plt.figure(figsize=(4,4))
plt.pie(data=df,x=val,labels=idx,autopct='%1f%%')
plt.title("Runtime Category distribution")
plt.show()
# Out:
# [9221 7160  363] Index(['Series', 'Long movie', 'Short movie'], dtype='object', name='runtime_category')

# %% [markdown]
# Observation - Maximum are series

# %% [markdown]
# Distribution of runtime

# %%
plt.figure(figsize=(7,7))
sns.kdeplot(df,x="Runtime")
plt.title("Distribution of runtime")
plt.show()

# %% [markdown]
# Observation - More movies with approximate 100 runtime

# %% [markdown]
# Get the correlation of numerical columns using heat map

# %%
correlation = df.corr(numeric_only=True)
plt.title('correlation of numerical columns')
sns.heatmap(correlation,annot=True)
plt.show()

# %% [markdown]
# Observation - Disney+ and ID have the strogest +ve relation(29%)

# %% [markdown]
# Trend of IMDb score across year

# %%
plt.figure(figsize=(7,7))
sns.lineplot(df,x="Year",y='IMDb')
plt.title("Trend of IMDb score across year")
plt.show()

# %% [markdown]
# Observation - Higher IMDb ratings before 1920

# %% [markdown]
# Plot the relationship betwen IMDb and Rotten Tomatoes

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(df,x="IMDb",y='Rotten Tomatoes')
plt.title("relationship betwen IMDb and Rotten Tomatoes")
plt.show()

# %% [markdown]
# Observation - Movies with Rotten Tomatoes 6 have IMDb ratings ranging form approximately 2 to 10

# %% [markdown]
# Detect the outliers in IMDb ratings

# %%
plt.figure(figsize=(7,7))
sns.boxplot(df,y="IMDb")
plt.title("outliers in IMDb ratings")
plt.show()

# %% [markdown]
# Observation - Lot of Movies with IMDb less than 2
