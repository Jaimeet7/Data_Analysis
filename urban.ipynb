# %% [markdown]
# # column description

# %% [markdown]
# segment_id → Unique ID for each road/catchment segment.
#
# city_name → City where the segment is located.
#
# admin_ward → Administrative ward/sector of the city.
#
# latitude, longitude → Geographic coordinates of the segment.
#
# catchment_id → ID for the catchment area (drainage basin).
#
# elevation_m → Elevation above sea level (in meters).
#
# dem_source → Source of elevation data (e.g., Copernicus, SRTM).
#
# land_use → Type of land use (Residential, Industrial, Institutional, etc.).
#
# soil_group → Soil classification (A, B, C, D) affecting infiltration.
#
# drainage_density_km_per_km2 → Drainage network density in the area.
#
# storm_drain_proximity_m → Distance to the nearest storm drain (meters).
#
# storm_drain_type → Type of drainage (Open Channel, Curb Inlet, Manhole, etc.).
#
# rainfall_source → Source of rainfall data (ERA5, IMD, etc.).
#
# historical_rainfall_intensity_mm_hr → Past rainfall intensity (mm/hr).
#
# return_period_years → Flood return period (5, 10, 25, 50 years).
#
# risk_labels → Flood risk status (e.g., monitor, ponding_hotspot, low_lying, with event date).

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('urban_pluvial_flood_risk_dataset.csv')
df
# Out:
#      segment_id             city_name    admin_ward   latitude   longitude  \
# 0     SEG-00001    Colombo, Sri Lanka  Borough East   6.920633   79.912600
# 1     SEG-00002        Chennai, India        Ward D  13.076487   80.281774
# 2     SEG-00003      Ahmedabad, India     Sector 12  23.019473   72.638578
# 3     SEG-00004      Hong Kong, China     Sector 14  22.302602  114.078673
# 4     SEG-00005  Durban, South Africa      Sector 5 -29.887602   30.911008
# ...         ...                   ...           ...        ...         ...
# 2958  SEG-02959         Paris, France        Ward B  48.872870    2.246250
# 2959  SEG-02960       Shanghai, China     Sector 17  31.195529  121.435540
# 2960  SEG-02961     Vancouver, Canada     Sector 12  49.162783 -123.037084
# 2961  SEG-02962        Lagos, Nigeria        Zone V   6.504570    3.388571
# 2962  SEG-02963          Osaka, Japan       Zone IV  34.740562  135.469263
#
#      catchment_id  elevation_m               dem_source       land_use  \
# 0         CAT-136          NaN     Copernicus_EEA-10_v5  Institutional
# 1         CAT-049        -2.19     Copernicus_EEA-10_v5    Residential
# 2         CAT-023        30.88                SRTM_3arc     Industrial
# 3         CAT-168        24.28                SRTM_3arc    Residential
# 4         CAT-171        35.70                SRTM_3arc     Industrial
# ...           ...          ...                      ...            ...
# 2958      CAT-036        30.46  Copernicus_GLO-30_v2023    Residential
# 2959      CAT-050        -3.00                SRTM_3arc     Industrial
# 2960      CAT-052        14.16  Copernicus_GLO-90_v2022          Green
# 2961      CAT-092         7.00  Copernicus_GLO-30_v2023     Industrial
# 2962      CAT-169        56.00                SRTM_3arc     Commercial
#
#      soil_group  drainage_density_km_per_km2  storm_drain_proximity_m  \
# 0           NaN                         4.27                    160.5
# 1             D                         7.54                      NaN
# 2             B                        11.00                    152.5
# 3             B                         7.32                     37.0
# 4             C                         4.50                    292.4
# ...         ...                          ...                      ...
# 2958          C                          NaN                     78.8
# 2959          C                         5.54                      4.9
# 2960          B                          NaN                    236.1
# 2961          B                         8.74                    294.8
# 2962          C                         4.44                     80.8
#
#      storm_drain_type rainfall_source  historical_rainfall_intensity_mm_hr  \
# 0           CurbInlet            ERA5                                 39.4
# 1         OpenChannel            ERA5                                 56.8
# 2         OpenChannel             IMD                                 16.3
# 3             Manhole            ERA5                                 77.0
# 4         OpenChannel            ERA5                                 20.8
# ...               ...             ...                                  ...
# 2958      GratedInlet             NaN                                 46.5
# 2959      OpenChannel      LocalGauge                                 70.6
# 2960      GratedInlet             NaN                                 27.7
# 2961      OpenChannel            ERA5                                131.6
# 2962      OpenChannel            ERA5                                 43.1
#
#       return_period_years                                 risk_labels
# 0                      50                                     monitor
# 1                      25  ponding_hotspot|low_lying|event_2025-05-02
# 2                       5                                     monitor
# 3                      10                                     monitor
# 4                       5                                     monitor
# ...                   ...                                         ...
# 2958                   10                                     monitor
# 2959                    5  ponding_hotspot|low_lying|event_2024-07-26
# 2960                    2                                     monitor
# 2961                  100              extreme_rain_history|low_lying
# 2962                    2                                     monitor
#
# [2963 rows x 17 columns]

# %%
# sns.boxplot(df['elevation_m']) - Too many outlier - replacing null with median
# For soil group(categorical column) - replacing with mode 
# sns.boxplot(df['drainage_density_km_per_km2']) - No outliers, replace with mean
# sns.boxplot(df['storm_drain_proximity_m']) - Too many outliers, replacing with median
# sns.boxplot(df['storm_drain_type']) - No outliers replace with mean
# df['rainfall_source'](categorical column) - replace with mode

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
md_elevation_m = df['elevation_m'].median()
m_soil_group = df['soil_group'].mode()[0]
mn_drainage_density_km_per_km2 = df['drainage_density_km_per_km2'].mean()
md_storm_drain_proximity_m = df['storm_drain_proximity_m'].median()
m_strom_drain_type = df['storm_drain_type'].mode()[0]
m_rainfall_source = df['rainfall_source'].mode()[0]

# %%
for col,val in zip(['elevation_m','soil_group','drainage_density_km_per_km2','storm_drain_proximity_m','storm_drain_type','rainfall_source'],[md_elevation_m,m_soil_group,mn_drainage_density_km_per_km2,md_storm_drain_proximity_m,m_strom_drain_type,m_rainfall_source]):
    df[col] = df[col].fillna(val)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2963 entries, 0 to 2962
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   segment_id                           2963 non-null   object
#  1   city_name                            2963 non-null   object
#  2   admin_ward                           2963 non-null   object
#  3   latitude                             2963 non-null   float64
#  4   longitude                            2963 non-null   float64
#  5   catchment_id                         2963 non-null   object
#  6   elevation_m                          2963 non-null   float64
#  7   dem_source                           2963 non-null   object
#  8   land_use                             2963 non-null   object
#  9   soil_group                           2963 non-null   object
#  10  drainage_density_km_per_km2          2963 non-null   float64
#  11  storm_drain_proximity_m              2963 non-null   float64
#  12  storm_drain_type                     2963 non-null   object
#  13  rainfall_source                      2963 non-null   object
#  14  historical_rainfall_intensity_mm_hr  2963 non-null   float64
#  15  return_period_years                  2963 non-null   int64
#  16  risk_labels                          2963 non-null   object
# dtypes: float64(6), int64(1), object(10)
# memory usage: 393.7+ KB

# %%
df['risk_labels'].unique()
# Out:
# array(['monitor', 'ponding_hotspot|low_lying|event_2025-05-02',
#        'extreme_rain_history', 'low_lying|event_2024-02-14', 'low_lying',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2024-09-25',
#        'monitor|event_2022-09-04',
#        'ponding_hotspot|low_lying|event_2024-07-31',
#        'ponding_hotspot|extreme_rain_history|event_2022-10-11',
#        'low_lying|sparse_drainage',
#        'ponding_hotspot|low_lying|event_2024-07-21',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2023-05-16',
#        'sparse_drainage', 'sparse_drainage|event_2024-05-19',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2023-09-13',
#        'low_lying|sparse_drainage|event_2023-07-20',
#        'extreme_rain_history|low_lying', 'ponding_hotspot|low_lying',
#        'ponding_hotspot|low_lying|event_2024-08-16',
#        'ponding_hotspot|low_lying|event_2024-03-31',
#        'low_lying|event_2024-03-24',
#        'ponding_hotspot|low_lying|event_2022-12-18',
#        'low_lying|event_2023-01-20', 'sparse_drainage|event_2022-10-13',
#        'ponding_hotspot|low_lying|event_2025-07-04',
#        'low_lying|event_2025-06-26', 'low_lying|event_2024-06-01',
#        'extreme_rain_history|sparse_drainage',
#        'ponding_hotspot|extreme_rain_history|low_lying|sparse_drainage|event_2023-08-25',
#        'ponding_hotspot|extreme_rain_history|low_lying',
#        'sparse_drainage|event_2025-05-16',
#        'extreme_rain_history|event_2023-12-22',
#        'ponding_hotspot|low_lying|event_2022-12-04',
#        'sparse_drainage|event_2022-09-01',
#        'ponding_hotspot|low_lying|event_2023-02-11',
#        'low_lying|event_2024-01-15',
#        'low_lying|sparse_drainage|event_2024-09-01',
#        'low_lying|event_2023-11-22', 'low_lying|event_2025-06-02',
#        'ponding_hotspot|low_lying|event_2023-06-06',
#        'low_lying|sparse_drainage|event_2025-05-30',
#        'extreme_rain_history|sparse_drainage|event_2025-03-31',
#        'ponding_hotspot|extreme_rain_history',
#        'ponding_hotspot|low_lying|event_2023-08-07',
#        'sparse_drainage|event_2023-02-21',
#        'low_lying|sparse_drainage|event_2023-03-26',
#        'monitor|event_2022-12-11',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2025-05-19',
#        'ponding_hotspot|extreme_rain_history|low_lying|sparse_drainage|event_2023-05-09',
#        'sparse_drainage|event_2025-06-17',
#        'extreme_rain_history|event_2025-04-20',
#        'sparse_drainage|event_2024-02-13', 'low_lying|event_2022-08-01',
#        'low_lying|sparse_drainage|event_2024-09-20',
#        'low_lying|event_2022-06-25',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2025-07-02',
#        'sparse_drainage|event_2024-01-05',
#        'ponding_hotspot|low_lying|event_2025-04-29',
#        'monitor|event_2025-04-25',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2023-11-14',
#        'ponding_hotspot|extreme_rain_history|event_2024-03-15',
#        'sparse_drainage|event_2022-07-18',
#        'extreme_rain_history|event_2024-07-25',
#        'low_lying|event_2024-01-09', 'sparse_drainage|event_2024-09-03',
#        'ponding_hotspot|low_lying|event_2023-12-23',
#        'sparse_drainage|event_2022-08-06', 'low_lying|event_2025-05-25',
#        'extreme_rain_history|event_2022-09-24',
#        'sparse_drainage|event_2023-02-13',
#        'ponding_hotspot|extreme_rain_history|low_lying|sparse_drainage|event_2022-08-02',
#        'sparse_drainage|event_2024-11-13',
#        'ponding_hotspot|extreme_rain_history|low_lying|sparse_drainage',
#        'ponding_hotspot|low_lying|event_2024-12-24',
#        'sparse_drainage|event_2023-10-01',
#        'sparse_drainage|event_2022-07-29',
#        'ponding_hotspot|low_lying|event_2023-06-21',
#        'ponding_hotspot|low_lying|event_2022-06-14',
#        'extreme_rain_history|low_lying|event_2025-04-14',
#        'low_lying|event_2022-06-11',
#        'ponding_hotspot|low_lying|event_2024-07-17',
#        'ponding_hotspot|low_lying|event_2023-11-11',
#        'sparse_drainage|event_2023-02-14',
#        'low_lying|sparse_drainage|event_2025-05-17',
#        'sparse_drainage|event_2025-02-13',
#        'ponding_hotspot|low_lying|event_2023-08-17',
#        'ponding_hotspot|low_lying|event_2023-05-11',
#        'extreme_rain_history|low_lying|event_2023-01-05',
#        'low_lying|event_2025-04-08',
#        'ponding_hotspot|extreme_rain_history|sparse_drainage',
#        'low_lying|event_2023-03-17', 'sparse_drainage|event_2024-06-28',
#        'ponding_hotspot|low_lying|event_2023-03-15',
#        'ponding_hotspot|low_lying|event_2023-08-19',
#        'ponding_hotspot|low_lying|event_2023-07-26',
#        'sparse_drainage|event_2024-01-13',
#        'ponding_hotspot|low_lying|event_2022-09-30',
#        'ponding_hotspot|low_lying|sparse_drainage',
#        'ponding_hotspot|low_lying|event_2024-08-19',
#        'extreme_rain_history|low_lying|sparse_drainage',
#        'ponding_hotspot|low_lying|event_2022-11-06', 'ponding_hotspot',
#        'ponding_hotspot|low_lying|event_2023-10-31',
#        'ponding_hotspot|low_lying|event_2025-06-06',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2024-02-13',
#        'low_lying|event_2023-06-15', 'low_lying|event_2023-12-15',
#        'low_lying|event_2023-12-17',
#        'ponding_hotspot|low_lying|event_2023-05-26',
#        'sparse_drainage|event_2024-06-20',
#        'extreme_rain_history|event_2024-08-06',
#        'extreme_rain_history|event_2025-03-20',
#        'ponding_hotspot|low_lying|event_2025-03-06',
#        'ponding_hotspot|low_lying|event_2023-05-20',
#        'sparse_drainage|event_2023-07-24',
#        'low_lying|sparse_drainage|event_2024-07-25',
#        'low_lying|event_2022-06-21',
#        'ponding_hotspot|low_lying|event_2024-02-27',
#        'low_lying|sparse_drainage|event_2025-04-11',
#        'ponding_hotspot|low_lying|event_2023-11-15',
#        'ponding_hotspot|extreme_rain_history|event_2023-01-01',
#        'low_lying|event_2022-07-22', 'sparse_drainage|event_2023-09-07',
#        'low_lying|event_2022-07-06',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2024-01-21',
#        'sparse_drainage|event_2022-12-31',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2023-01-10',
#        'sparse_drainage|event_2023-12-14', 'low_lying|event_2025-01-02',
#        'sparse_drainage|event_2024-06-03',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2024-08-18',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2025-05-25',
#        'ponding_hotspot|low_lying|event_2023-05-13',
#        'ponding_hotspot|low_lying|event_2024-03-08',
#        'sparse_drainage|event_2022-09-20',
#        'ponding_hotspot|low_lying|event_2025-05-04',
#        'low_lying|event_2023-08-15',
#        'ponding_hotspot|low_lying|sparse_drainage|event_2024-05-11',
#        'ponding_hotspot|low_lying|event_2024-09-17',
#        'low_lying|sparse_drainage|event_2024-09-02',
#        'sparse_drainage|event_2022-08-03',
#        'extreme_rain_history|sparse_drainage|event_2023-03-23',
#        'extreme_rain_history|event_2023-07-09',
#        'ponding_hotspot|low_lying|event_2024-01-23',
#        'sparse_drainage|event_2023-07-11', 'low_lying|event_2024-09-05',
#        'low_lying|sparse_drainage|event_2023-02-15',
#        'ponding_hotspot|extreme_rain_history|event_2024-02-18',
#        'ponding_hotspot|low_lying|event_2023-12-01',
#        'ponding_hotspot|extreme_rain_history|event_2023-09-29',
#        'ponding_hotspot|low_lying|event_2025-03-11',
#        'extreme_rain_history|event_2022-05-07',
#        'ponding_hotspot|low_lying|event_2022-07-25',
#        'ponding_hotspot|low_lying|event_2022-08-29',
#        'ponding_hotspot|low_lying|event_2024-09-14',
#        'low_lying|sparse_drainage|event_2023-11-02',
#        'ponding_hotspot|extreme_rain_history|event_2024-02-20',
#        'ponding_hotspot|extreme_rain_history|event_2022-10-28',
#        'sparse_drainage|event_2023-12-05',
#        'sparse_drainage|event_2022-06-11',
#        'sparse_drainage|event_2024-05-25', 'low_lying|event_2023-07-31',
#        'sparse_drainage|event_2022-11-02',
#        'ponding_hotspot|extreme_rain_history|event_2023-02-27',
#        'low_lying|event_2025-03-09',
#        'extreme_rain_history|event_2024-04-12',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2023-05-07',
#        'ponding_hotspot|low_lying|event_2024-12-02',
#        'ponding_hotspot|low_lying|event_2025-01-02',
#        'extreme_rain_history|sparse_drainage|event_2023-02-06',
#        'sparse_drainage|event_2024-01-02',
#        'ponding_hotspot|low_lying|event_2024-07-26',
#        'extreme_rain_history|event_2022-05-08',
#        'ponding_hotspot|low_lying|event_2024-01-02',
#        'extreme_rain_history|event_2024-12-25',
#        'sparse_drainage|event_2023-01-26', 'low_lying|event_2022-10-14',
#        'extreme_rain_history|low_lying|sparse_drainage|event_2022-09-19',
#        'ponding_hotspot|low_lying|event_2025-01-13',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2022-06-10',
#        'ponding_hotspot|low_lying|event_2025-05-10',
#        'sparse_drainage|event_2024-07-24',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2025-04-08',
#        'low_lying|event_2023-01-15',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2024-12-20',
#        'sparse_drainage|event_2024-03-18',
#        'sparse_drainage|event_2023-02-08',
#        'ponding_hotspot|low_lying|event_2023-03-17',
#        'ponding_hotspot|low_lying|event_2024-06-25',
#        'low_lying|event_2022-07-30',
#        'ponding_hotspot|extreme_rain_history|event_2023-11-12',
#        'low_lying|event_2025-05-06',
#        'ponding_hotspot|extreme_rain_history|low_lying|event_2025-06-09',
#        'ponding_hotspot|extreme_rain_history|event_2023-07-03',
#        'extreme_rain_history|low_lying|event_2023-11-07'], dtype=object)

# %%
df['risk_labels'] = df['risk_labels'].str.split('|')
def f1(d):
    risk = []
    for i in d['risk_labels']:
        if 'event' in i:
            d['event'] = i
        elif 'lying' in i:
            d['level'] = i
        else:
            risk.append(i)
            d['risks'] = '|'.join(risk)
    return d
df = df.apply(f1,axis=1)
df['risks'].unique()
# Out:
# array(['monitor', 'ponding_hotspot', 'extreme_rain_history', nan,
#        'ponding_hotspot|extreme_rain_history', 'sparse_drainage',
#        'extreme_rain_history|sparse_drainage',
#        'ponding_hotspot|extreme_rain_history|sparse_drainage',
#        'ponding_hotspot|sparse_drainage'], dtype=object)

# %%
# df['risk_labels'] = df['risk_labels'].str.split('|')
# df['risk'] = [i[0] for i in df['risk_labels']]
# df['event'] = [i[1] if len(i)>1 else None for i in df['risk_labels']]
# df['level'] = [i[1] if len(i)>2 else None for i in df['risk_labels']]
# df = df.drop(columns="risk_labels")

# %% [markdown]
# # Analysis

# %% [markdown]
# 5. ------------------------------------------------Location Insights------------------------------------------------
#
# Which city has the highest number of flood hotspots?
#
# Within a city, which wards are most affected?
#
# 6.------------------------------------------------Combined Factors & Trends------------------------------------------------
#
# Which 2–3 factors combined (e.g., low elevation + residential + high rainfall) appear most often in risky areas?
#
# What patterns or trends can be seen in the dataset overall?
#
# 7.------------------------------------------------Decision & Action------------------------------------------------
#
# Which areas (or regions) are at highest risk of flooding?
#
# Which locations must be prioritized for flood prevention measures?
#
# Which areas are safest for new houses or infrastructure?
#
# Which villages/towns need early flood warning systems immediately?
#
# Should resources (funds, manpower) be focused on high rainfall zones, clay soil regions, or urbanized areas?
#
# What is the top recommendation for reducing flood risk in this region?

# %% [markdown]
# 1. ----------------------------------------------------Dataset Basics-------------------------------------------------
#
# How many total records are there in the dataset?
#
# What are the different risk_labels?
#
# How many segments fall under each risk label?

# %%
len(df)
# Out:
# 2963

# %% [markdown]
# Observation - Total records = 2963

# %%
df['risks'].unique()
# Out:
# array(['monitor', 'ponding_hotspot', 'extreme_rain_history', nan,
#        'ponding_hotspot|extreme_rain_history', 'sparse_drainage',
#        'extreme_rain_history|sparse_drainage',
#        'ponding_hotspot|extreme_rain_history|sparse_drainage',
#        'ponding_hotspot|sparse_drainage'], dtype=object)

# %%
df.groupby('risks')['segment_id'].count()
# Out:
# risks
# extreme_rain_history                                     162
# extreme_rain_history|sparse_drainage                      11
# monitor                                                 1994
# ponding_hotspot                                          134
# ponding_hotspot|extreme_rain_history                      75
# ponding_hotspot|extreme_rain_history|sparse_drainage       6
# ponding_hotspot|sparse_drainage                            7
# sparse_drainage                                          157
# Name: segment_id, dtype: int64

# %% [markdown]
# 2. -------------------------------------------------Geography & Environment----------------------------------------------
#
# Do low elevation areas have more flood risk than high elevation areas?
#
# Which soil type (A–D) is most common in risky areas?
#
# Which land use type (Residential, Industrial, Institutional) shows the highest flood risk?

# %%
df
# Out:
#         admin_ward catchment_id             city_name  \
# 0     Borough East      CAT-136    Colombo, Sri Lanka
# 1           Ward D      CAT-049        Chennai, India
# 2        Sector 12      CAT-023      Ahmedabad, India
# 3        Sector 14      CAT-168      Hong Kong, China
# 4         Sector 5      CAT-171  Durban, South Africa
# ...            ...          ...                   ...
# 2958        Ward B      CAT-036         Paris, France
# 2959     Sector 17      CAT-050       Shanghai, China
# 2960     Sector 12      CAT-052     Vancouver, Canada
# 2961        Zone V      CAT-092        Lagos, Nigeria
# 2962       Zone IV      CAT-169          Osaka, Japan
#
#                    dem_source  drainage_density_km_per_km2  elevation_m  \
# 0        Copernicus_EEA-10_v5                     4.270000        25.13
# 1        Copernicus_EEA-10_v5                     7.540000        -2.19
# 2                   SRTM_3arc                    11.000000        30.88
# 3                   SRTM_3arc                     7.320000        24.28
# 4                   SRTM_3arc                     4.500000        35.70
# ...                       ...                          ...          ...
# 2958  Copernicus_GLO-30_v2023                     6.290866        30.46
# 2959                SRTM_3arc                     5.540000        -3.00
# 2960  Copernicus_GLO-90_v2022                     6.290866        14.16
# 2961  Copernicus_GLO-30_v2023                     8.740000         7.00
# 2962                SRTM_3arc                     4.440000        56.00
#
#                  event  historical_rainfall_intensity_mm_hr       land_use  \
# 0                  NaN                                 39.4  Institutional
# 1     event_2025-05-02                                 56.8    Residential
# 2                  NaN                                 16.3     Industrial
# 3                  NaN                                 77.0    Residential
# 4                  NaN                                 20.8     Industrial
# ...                ...                                  ...            ...
# 2958               NaN                                 46.5    Residential
# 2959  event_2024-07-26                                 70.6     Industrial
# 2960               NaN                                 27.7          Green
# 2961               NaN                                131.6     Industrial
# 2962               NaN                                 43.1     Commercial
#
#        latitude      level   longitude rainfall_source  return_period_years  \
# 0      6.920633        NaN   79.912600            ERA5                   50
# 1     13.076487  low_lying   80.281774            ERA5                   25
# 2     23.019473        NaN   72.638578             IMD                    5
# 3     22.302602        NaN  114.078673            ERA5                   10
# 4    -29.887602        NaN   30.911008            ERA5                    5
# ...         ...        ...         ...             ...                  ...
# 2958  48.872870        NaN    2.246250            ERA5                   10
# 2959  31.195529  low_lying  121.435540      LocalGauge                    5
# 2960  49.162783        NaN -123.037084            ERA5                    2
# 2961   6.504570  low_lying    3.388571            ERA5                  100
# 2962  34.740562        NaN  135.469263            ERA5                    2
#
#                                          risk_labels                 risks  \
# 0                                          [monitor]               monitor
# 1     [ponding_hotspot, low_lying, event_2025-05-02]       ponding_hotspot
# 2                                          [monitor]               monitor
# 3                                          [monitor]               monitor
# 4                                          [monitor]               monitor
# ...                                              ...                   ...
# 2958                                       [monitor]               monitor
# 2959  [ponding_hotspot, low_lying, event_2024-07-26]       ponding_hotspot
# 2960                                       [monitor]               monitor
# 2961               [extreme_rain_history, low_lying]  extreme_rain_history
# 2962                                       [monitor]               monitor
#
#      segment_id soil_group  storm_drain_proximity_m storm_drain_type
# 0     SEG-00001          B                    160.5        CurbInlet
# 1     SEG-00002          D                     91.7      OpenChannel
# 2     SEG-00003          B                    152.5      OpenChannel
# 3     SEG-00004          B                     37.0          Manhole
# 4     SEG-00005          C                    292.4      OpenChannel
# ...         ...        ...                      ...              ...
# 2958  SEG-02959          C                     78.8      GratedInlet
# 2959  SEG-02960          C                      4.9      OpenChannel
# 2960  SEG-02961          B                    236.1      GratedInlet
# 2961  SEG-02962          B                    294.8      OpenChannel
# 2962  SEG-02963          C                     80.8      OpenChannel
#
# [2963 rows x 20 columns]

# %%
high_level = pd.DataFrame(df.loc[df['elevation_m']>25,['risks']])
high_level['risks'].value_counts()
# Out:
# risks
# monitor                                 1400
# sparse_drainage                           93
# extreme_rain_history                      63
# extreme_rain_history|sparse_drainage       5
# ponding_hotspot|extreme_rain_history       4
# Name: count, dtype: int64

# %%
low_level = pd.DataFrame(df.loc[df['elevation_m']<25,['risks']])
low_level['risks'].value_counts()
# Out:
# risks
# monitor                                                 594
# ponding_hotspot                                         134
# extreme_rain_history                                     99
# ponding_hotspot|extreme_rain_history                     71
# sparse_drainage                                          64
# ponding_hotspot|sparse_drainage                           7
# extreme_rain_history|sparse_drainage                      6
# ponding_hotspot|extreme_rain_history|sparse_drainage      6
# Name: count, dtype: int64

# %% [markdown]
# Observation - High level areas are at less risk of drainage as most of their drainage's are monitored

# %%
df.loc[df['risks']!="monitor",['soil_group']].value_counts()
# Out:
# soil_group
# B             380
# C             213
# D             199
# A             177
# Name: count, dtype: int64

# %% [markdown]
# Observation - B is the most common soil type in risky areas

# %%
df.loc[df['risks']!= 'monitor',['land_use']].value_counts()
# Out:
# land_use
# Residential      292
# Roads            182
# Green            148
# Commercial       136
# Industrial       100
# Mixed             38
# Institutional     34
# Water             33
# Informal           6
# Name: count, dtype: int64

# %% [markdown]
# 3. ------------------------------------------------Infrastructure------------------------------------------------
#
# Are places closer to drains safer compared to those far away?
#
# Which drain type (Open Channel, Manhole, Curb Inlet) is seen more in risky areas?

# %%
df.loc[df['risks']!='monitor'].groupby('storm_drain_type')['storm_drain_type'].count()
# Out:
# storm_drain_type
# CurbInlet      326
# GratedInlet    203
# Manhole        252
# OpenChannel    188
# Name: storm_drain_type, dtype: int64

# %%
df.loc[df['risks']!='monitor',['storm_drain_type']].value_counts()
# Out:
# storm_drain_type
# CurbInlet           326
# Manhole             252
# GratedInlet         203
# OpenChannel         188
# Name: count, dtype: int64

# %%
df
# Out:
#         admin_ward catchment_id             city_name  \
# 0     Borough East      CAT-136    Colombo, Sri Lanka
# 1           Ward D      CAT-049        Chennai, India
# 2        Sector 12      CAT-023      Ahmedabad, India
# 3        Sector 14      CAT-168      Hong Kong, China
# 4         Sector 5      CAT-171  Durban, South Africa
# ...            ...          ...                   ...
# 2958        Ward B      CAT-036         Paris, France
# 2959     Sector 17      CAT-050       Shanghai, China
# 2960     Sector 12      CAT-052     Vancouver, Canada
# 2961        Zone V      CAT-092        Lagos, Nigeria
# 2962       Zone IV      CAT-169          Osaka, Japan
#
#                    dem_source  drainage_density_km_per_km2  elevation_m  \
# 0        Copernicus_EEA-10_v5                     4.270000        25.13
# 1        Copernicus_EEA-10_v5                     7.540000        -2.19
# 2                   SRTM_3arc                    11.000000        30.88
# 3                   SRTM_3arc                     7.320000        24.28
# 4                   SRTM_3arc                     4.500000        35.70
# ...                       ...                          ...          ...
# 2958  Copernicus_GLO-30_v2023                     6.290866        30.46
# 2959                SRTM_3arc                     5.540000        -3.00
# 2960  Copernicus_GLO-90_v2022                     6.290866        14.16
# 2961  Copernicus_GLO-30_v2023                     8.740000         7.00
# 2962                SRTM_3arc                     4.440000        56.00
#
#                  event  historical_rainfall_intensity_mm_hr       land_use  \
# 0                  NaN                                 39.4  Institutional
# 1     event_2025-05-02                                 56.8    Residential
# 2                  NaN                                 16.3     Industrial
# 3                  NaN                                 77.0    Residential
# 4                  NaN                                 20.8     Industrial
# ...                ...                                  ...            ...
# 2958               NaN                                 46.5    Residential
# 2959  event_2024-07-26                                 70.6     Industrial
# 2960               NaN                                 27.7          Green
# 2961               NaN                                131.6     Industrial
# 2962               NaN                                 43.1     Commercial
#
#        latitude      level   longitude rainfall_source  return_period_years  \
# 0      6.920633        NaN   79.912600            ERA5                   50
# 1     13.076487  low_lying   80.281774            ERA5                   25
# 2     23.019473        NaN   72.638578             IMD                    5
# 3     22.302602        NaN  114.078673            ERA5                   10
# 4    -29.887602        NaN   30.911008            ERA5                    5
# ...         ...        ...         ...             ...                  ...
# 2958  48.872870        NaN    2.246250            ERA5                   10
# 2959  31.195529  low_lying  121.435540      LocalGauge                    5
# 2960  49.162783        NaN -123.037084            ERA5                    2
# 2961   6.504570  low_lying    3.388571            ERA5                  100
# 2962  34.740562        NaN  135.469263            ERA5                    2
#
#                                          risk_labels                 risks  \
# 0                                          [monitor]               monitor
# 1     [ponding_hotspot, low_lying, event_2025-05-02]       ponding_hotspot
# 2                                          [monitor]               monitor
# 3                                          [monitor]               monitor
# 4                                          [monitor]               monitor
# ...                                              ...                   ...
# 2958                                       [monitor]               monitor
# 2959  [ponding_hotspot, low_lying, event_2024-07-26]       ponding_hotspot
# 2960                                       [monitor]               monitor
# 2961               [extreme_rain_history, low_lying]  extreme_rain_history
# 2962                                       [monitor]               monitor
#
#      segment_id soil_group  storm_drain_proximity_m storm_drain_type
# 0     SEG-00001          B                    160.5        CurbInlet
# 1     SEG-00002          D                     91.7      OpenChannel
# 2     SEG-00003          B                    152.5      OpenChannel
# 3     SEG-00004          B                     37.0          Manhole
# 4     SEG-00005          C                    292.4      OpenChannel
# ...         ...        ...                      ...              ...
# 2958  SEG-02959          C                     78.8      GratedInlet
# 2959  SEG-02960          C                      4.9      OpenChannel
# 2960  SEG-02961          B                    236.1      GratedInlet
# 2961  SEG-02962          B                    294.8      OpenChannel
# 2962  SEG-02963          C                     80.8      OpenChannel
#
# [2963 rows x 20 columns]

# %% [markdown]
# 4. ------------------------------------------------Rainfall------------------------------------------------
#
# Do areas with higher rainfall intensity face more flooding?
#
# Does flood risk increase with longer return periods (5 vs 25 vs 50 years)?

# %%
df.loc[df['historical_rainfall_intensity_mm_hr']>43,['risks']].value_counts()
# Out:
# risks
# monitor                                                 658
# extreme_rain_history                                    162
# ponding_hotspot                                          81
# ponding_hotspot|extreme_rain_history                     75
# sparse_drainage                                          53
# extreme_rain_history|sparse_drainage                     11
# ponding_hotspot|extreme_rain_history|sparse_drainage      6
# ponding_hotspot|sparse_drainage                           4
# Name: count, dtype: int64

# %%
df.loc[df['historical_rainfall_intensity_mm_hr']<43,["risks"]].value_counts()
# Out:
# risks
# monitor                            1335
# sparse_drainage                     104
# ponding_hotspot                      53
# ponding_hotspot|sparse_drainage       3
# Name: count, dtype: int64

# %% [markdown]
# Observation - Area with higher rainfall intensity have lesser flood monitoring and are therefore more prone to flooding

# %%
df.groupby('return_period_years')['']
